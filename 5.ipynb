# %%
# フォント設定
from matplotlib import rcParams
rcParams['font.family'] = 'Noto Sans CJK JP'

# %% [markdown]
# # 🟦 正規分布 (Normal distribution)
#
# * 平均を中心に左右対称の釣鐘型の分布。自然現象や測定誤差など、多くの事象で現れる基本的な分布。
# * 連続

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# パラメータ
mu = 0      # 平均μ
sigma = 1   # 標準偏差σ

# x軸の範囲
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)

# 正規分布の確率密度関数
y = norm.pdf(x, mu, sigma)

# グラフ描画
plt.plot(x, y, label=f'N({mu}, {sigma**2})')
plt.title('Normal Distribution')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### np.linspace
#
# `np.linspace(start, stop, num)` は、指定した区間 `[start, stop]` を等間隔に分割した数列を生成する関数。
# ここでは `mu - 4*sigma` から `mu + 4*sigma` までを1000分割した配列を作り、グラフのx軸の値として使っている。
#
# ---
#
# ### norm.pdf
#
# `scipy.stats.norm.pdf(x, loc, scale)` は正規分布の確率密度関数 (Probability Density Function) の値を返す関数。
#
# * `x`: 評価する点
# * `loc`: 平均値（ここでは `mu`）
# * `scale`: 標準偏差（ここでは `sigma`）
#
# 結果として、各 `x` に対応する正規分布の高さを計算している。
#
# ---
#
# ### label=f'N({mu}, {sigma**2})'
#
# Python の **f文字列 (f-string)** で、変数を文字列に埋め込んでいる。
#
# * `mu` → 平均
# * `sigma**2` → 分散（標準偏差の2乗）
#
# このコードでは凡例に `N(平均, 分散)` の形を自動的に表示する。
# 例えば `mu=0, sigma=1` なら `"N(0, 1)"` がラベルになる。

# %% [markdown]
# # 🟦 二項分布 (Binomial distribution)
#
# * 一定の試行回数の中で、成功・失敗の二値が起こる確率を表す分布。例えば「コインを10回投げて表が出る回数」。
# * 離散

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# パラメータ
n = 20   # 試行回数
p = 0.5  # 成功確率

# xの範囲
x = np.arange(0, n+1)

# 確率質量関数 (PMF)
pmf = binom.pmf(x, n, p)

# グラフ描画
plt.bar(x, pmf, tick_label=x)
plt.xlabel("成功回数")
plt.ylabel("確率")
plt.title(f"二項分布 (n={n}, p={p})")
plt.show()

# %% [markdown]
# * `pmf` は 確率質量関数 (probability mass function) の略です。

# %% [markdown]
# # 🟦 幾何分布(Geometric distribution)
#
# * 離散
# * 最初に成功が出るまでの試行回数を表す分布。例えば「コインを投げて初めて表が出るまでにかかる回数」。

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import geom

# パラメータ
p = 0.3 # 成功確率

k = np.arange(1, 15)
pmf = geom.pmf(k, p)

plt.bar(k, pmf)
plt.xlabel("試行回数 (k)")
plt.ylabel("確率質量関数 P(X=k)")
plt.title(f"幾何分布 (p={p})")
plt.show()

# %% [markdown]
# # 🟦 ポアソン分布(Poisson distribution)
#
# * 一定時間内でまれに起こる事象の回数を表す分布。例えば「1時間に起こる交通事故の件数」。
# * 単位時間内に平均λ回発生する事象がk回発生する確率の分布。当然λ回発生するケースが一番確率が高い。
# * 離散

# %% [markdown]
# $ \Huge P(X = k) = \frac{\lambda^k e^{-\lambda}}{k!}, \quad k = 0,1,2,\dots $
#
# $ \Huge E[X] = \lambda $
#
# $ \Huge \mathrm{Var}(X) = \lambda $

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# パラメータ
lam = 4 # 平均発生回数 (λ)

# x 軸の範囲
x = np.arange(0, 15)

# ポアソン分布の確率質量関数
pmf = poisson.pmf(x, lam)

# 棒グラフで描画
plt.bar(x, pmf)
plt.title(f"Poisson Distribution (λ={lam})")
plt.xlabel("k")
plt.ylabel("P(X=k)")
plt.show()

# %% [markdown]
# # 🟦 一様分布 (Uniform distribution)
#
# * ある範囲内の値が等しい確率で出現する分布。例えば「乱数で0から1を一様に選ぶ」。
# * 連続

# %%
import numpy as np
import matplotlib.pyplot as plt

# パラメータ
a, b = 0, 1 # 一様分布の範囲

# データ生成
x = np.linspace(a - 0.5, b + 0.5, 1000)
y = np.where((x >= a) & (x <= b), 1 / (b - a), 0)

# プロット
plt.plot(x, y, label=f'Uniform({a}, {b})')
plt.xlabel('x')
plt.ylabel('確率密度')
plt.title('一様分布')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # 🟦 指数分布 (Exponential distribution)
#
# * ポアソン過程における事象の発生間隔を表す分布。例えば「バスが来るまでの待ち時間」。
# * 連続

# %%
import numpy as np
import matplotlib.pyplot as plt

# パラメータ
lam = 1.5 # 平均発生回数 (λ)

# x軸の範囲
x = np.linspace(0, 5, 1000)

# 指数分布の確率密度関数
pdf = lam * np.exp(-lam * x)

# グラフ描画
plt.plot(x, pdf, label=f'λ={lam}')
plt.title("指数分布 (Exponential Distribution)")
plt.xlabel("x")
plt.ylabel("確率密度")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # 🟦 ガンマ分布 (Gamma distribution)
#
# * 複数の指数分布の和として現れる分布。待ち時間が積み重なる状況を表現できる。
# * 連続

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gamma

# パラメータ
k = 2.0   # 形状母数
theta = 2.0  # 尺度母数

x = np.linspace(0, 20, 1000)
y = gamma.pdf(x, a=k, scale=theta)

plt.plot(x, y, label=f'Gamma(k={k}, θ={theta})')
plt.title("Gamma Distribution")
plt.xlabel("x")
plt.ylabel("Density")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # 🟦 カイ２乗分布 (Chi-square distribution)
#
# * 標準正規分布の二乗和で得られる分布。統計的な検定や分散分析でよく使われる。
# * 連続

# %%
# カイ2乗分布（確率密度関数）を描画するシンプルな例
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

# パラメータ
df = 5 # 自由度

# x 範囲（上側 99.9%点までを描画範囲にする）
x = np.linspace(0, chi2.ppf(0.999, df), 600)

# 確率密度関数（PDF）
y = chi2.pdf(x, df)

plt.figure(figsize=(6, 4))
plt.plot(x, y, lw=2, label=f"df={df}")
plt.xlabel("x")
plt.ylabel("確率密度")
plt.title("カイ2乗分布（PDF）")
plt.grid(True, alpha=0.4)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # 🟦 t分布 (Student's t distribution)
#
# * 母分散が未知のときに標本平均の推測に用いられる分布。正規分布に似ているが裾が厚い。
# * 連続

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import t

# パラメータ
df = 10 # 自由度

# x軸の範囲
x = np.linspace(-5, 5, 500)

# t分布の確率密度関数
y = t.pdf(x, df)

# 描画
plt.plot(x, y, label=f't分布 (自由度={df})')
plt.title("t分布")
plt.xlabel("x")
plt.ylabel("確率密度")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # 🟦 f分布 (F distribution)
#
# * 二つの独立したカイ二乗分布の比から得られる分布。分散分析 (ANOVA) などで利用される。
# * 連続

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f

# パラメータ
dof1, dof2 = 5, 10 # 分子の自由度、分母の自由度

# xの範囲
x = np.linspace(0, 5, 500)

# F分布の確率密度関数
y = f.pdf(x, dof1, dof2)

# 描画
plt.plot(x, y, label=f"F分布 (df1={dof1}, df2={dof2})")
plt.title("F分布")
plt.xlabel("x")
plt.ylabel("確率密度")
plt.legend()
plt.grid(True)
plt.show()
